# %%
import email
from email.parser import Parser
import os
import shutil
import emails_dictionary
import csv

# %%
def emails_are_equal(content1, content2):
    parser = Parser()
    email1 = parser.parsestr(content1)
    email2 = parser.parsestr(content2)
    
    headers_to_compare = ['Date', 'From', 'To', 'Subject']
    
    for header in headers_to_compare:
        if email1[header] != email2[header]:
            return False

    if email1.get_payload() != email2.get_payload():
        return False
    
    return True

# %%
def is_email_address_in_to_field(to_field, email_address_list):
    # Split the 'To' field into a list of email addresses
    to_emails = to_field.split(', ')
    # Check if any of the email addresses in the 'To' field is in the email_address_list
    return any(email.strip() in email_address_list for email in to_emails)

# %%
def create_all_sent_and_all_received_directories(person, email_addresses):
    rootdir = os.getcwd() + '/enron_mail/maildir/' + person  # Set the path to your maildir

    # List all items in rootdir
    items = os.listdir(rootdir)

    # Construct paths for the new directories
    all_sent_dir = os.path.join(rootdir, 'all_sent')
    all_received_dir = os.path.join(rootdir, 'all_received')

    # Create the directories if they don't exist
    if not os.path.exists(all_sent_dir):
        os.makedirs(all_sent_dir)
    if not os.path.exists(all_received_dir):
        os.makedirs(all_received_dir)

    for item in items:
        if item == 'all_sent' or item == 'all_received':
            continue
        # Construct the full path
        item_path = os.path.join(rootdir, item)

        # Check if the item is a directory
        if os.path.isdir(item_path):

            # List all items in the current directory
            sub_items = os.listdir(item_path)

            for sub_item in sub_items:
                # Construct the full path
                sub_item_path = os.path.join(item_path, sub_item)

                # Check if the item is a file
                if os.path.isfile(sub_item_path):
                    # Open the file
                    with open(sub_item_path, 'r', errors='ignore') as file:
                        # Read the content of the file
                        content = file.read()

                        # Parse the content of the file
                        parser = Parser()
                        email = parser.parsestr(content)

                        if email['From'] in email_addresses:
                            shutil.copy(sub_item_path, all_sent_dir)
                        elif email['To'] and is_email_address_in_to_field(email['To'], email_addresses):
                            shutil.copy(sub_item_path, all_received_dir)
                        else:
                            pass

# %%
def drop_duplicated_emails(directory):
    # List all items in the directory
    all_items = os.listdir(directory)

    for item in all_items:
        # Construct the full path
        item_path = os.path.join(directory, item)
        
        # Check if the item is a file
        if os.path.isfile(item_path):
            # Open the file
            with open(item_path, 'r', errors='ignore') as file:
                # Read the content of the file
                content = file.read()
                                
                # List all items in the directory
                all_items = os.listdir(directory)
                
                for other_item in all_items:
                    # Construct the full path
                    other_item_path = os.path.join(directory, other_item)
                    
                    # Check if the item is a file
                    if os.path.isfile(other_item_path) and other_item_path != item_path:
                        # Open the file
                        with open(other_item_path, 'r', errors='ignore') as other_file:
                            # Read the content of the file
                            other_content = other_file.read()
                            
                            # Check if the emails are equal
                            if emails_are_equal(content, other_content):
                                # Remove the duplicate
                                os.remove(other_item_path)

# %%
for person in emails_dictionary.emails:
    email_addresses = emails_dictionary.emails[person]
    create_all_sent_and_all_received_directories(person, email_addresses)
    drop_duplicated_emails(os.getcwd() + '/enron_mail/maildir/' + person + '/all_sent')
    drop_duplicated_emails(os.getcwd() + '/enron_mail/maildir/' + person + '/all_received')
    print(person + ' done')
# Out:
# davis-d done
# stepenovitch-j done
# king-j done
# campbell-l done
# shapiro-r done
# symes-k done
# storey-g done
# kuykendall-t done
# hodge-j done
# crandell-s done
# lewis-a done
# shankman-j done
# pereira-s done
# whalley-g done
# south-s done
# taylor-m done
# dasovich-j done
# horton-s done
# shackleton-s done
# ring-a done
# may-l done
# lokey-t done
# bailey-s done
# fischer-m done
# arora-h done
# lay-k done
# kitchen-l done
# donoho-l done
# delainey-d done
# rogers-b done
# lenhart-m done
# hayslett-r done
# blair-l done
# mckay-b done
# buy-r done
# linder-e done
# sager-e done
# ruscitti-k done
# mims-thurston-p done
# thomas-p done
# corman-s done
# mclaughlin-e done
# swerzbin-m done
# steffes-j done
# martin-t done
# maggi-m done
# donohoe-t done
# mann-k done
# zufferli-j done
# tholt-j done
# sanders-r done
# platter-p done
# benson-r done
# brawner-s done
# carson-m done
# mccarty-d done
# keiser-k done
# dean-c done
# bass-e done
# ermis-f done
# perlingiere-d done
# staab-t done
# geaccone-t done
# gilbertsmith-d done
# harris-s done
# parks-j done
# sturm-f done
# love-p done
# kaminski-v done
# motley-m done
# shively-h done
# meyers-a done
# dickson-s done
# saibi-e done
# dorland-c done
# lokay-m done
# merriss-s done
# jones-t done
# rapp-b done
# nemec-g done
# skilling-j done
# stclair-c done
# cuilla-m done
# keavey-p done
# solberg-g done
# holst-k done
# rodrique-r done
# ybarbo-p done
# lucci-p done
# salisbury-h done
# grigsby-m done
# stokley-c done
# haedicke-m done
# pimenov-v done
# guzman-m done
# quenet-j done
# scott-s done
# ward-k done
# panus-s done
# allen-p done
# presto-k done
# ring-r done
# mcconnell-m done
# hendrickson-s done
# smith-m done
# williams-w3 done
# griffith-j done
# scholtes-d done
# arnold-j done
# reitmeyer-j done
# watson-k done
# gay-r done
# giron-d done
# weldon-c done
# williams-j done
# whalley-l done
# schoolcraft-d done
# white-s done
# lavorato-j done
# badeer-r done
# derrick-j done
# sanchez-m done
# hain-m done
# richey-c done
# quigley-d done
# heard-m done
# phanis-s done
# schwieger-j done
# zipper-a done
# gang-l done
# causholli-m done
# semperger-c done
# townsend-j done
# neal-s done
# fossum-d done
# mckay-j done
# beck-s done
# hyvl-d done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 5
#       3 create_all_sent_and_all_received_directories(person, email_addresses)
#       4 drop_duplicated_emails(os.getcwd() + '/enron_mail/maildir/' + person + '/all_sent')
# ----> 5 drop_duplicated_emails(os.getcwd() + '/enron_mail/maildir/' + person + '/all_received')
#       6 print(person + ' done')
#
# Cell In[11], line 26, in drop_duplicated_emails(directory)
#      23 # Check if the item is a file
#      24 if os.path.isfile(other_item_path) and other_item_path != item_path:
#      25     # Open the file
# ---> 26     with open(other_item_path, 'r', errors='ignore') as other_file:
#      27         # Read the content of the file
#      28         other_content = other_file.read()
#      30         # Check if the emails are equal
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# File ~/anaconda3/envs/ml/lib/python3.10/codecs.py:309, in BufferedIncrementalDecoder.__init__(self, errors)
#     303 class BufferedIncrementalDecoder(IncrementalDecoder):
#     304     """
#     305     This subclass of IncrementalDecoder can be used as the baseclass for an
#     306     incremental decoder if the decoder must be able to handle incomplete
#     307     byte sequences.
#     308     """
# --> 309     def __init__(self, errors='strict'):
#     310         IncrementalDecoder.__init__(self, errors)
#     311         # undecoded input that is kept between calls to decode()
#
# KeyboardInterrupt:

# %%
for person in emails_dictionary.emails:
    # count all_sent and all_received
    all_sent_dir = os.path.join(os.getcwd() + '/enron_mail/maildir/' + person, 'all_sent')
    all_received_dir = os.path.join(os.getcwd() + '/enron_mail/maildir/' + person, 'all_received')
    try:
        all_sent_items = os.listdir(all_sent_dir)
        all_received_items = os.listdir(all_received_dir)
        print(person + ' all_sent: ' + str(len(all_sent_items)))
        print(person + ' all_received: ' + str(len(all_received_items)))
    except:
        continue
# Out:
# davis-d all_sent: 276
# davis-d all_received: 325
# stepenovitch-j all_sent: 83
# stepenovitch-j all_received: 279
# king-j all_sent: 18
# king-j all_received: 215
# campbell-l all_sent: 351
# campbell-l all_received: 931
# shapiro-r all_sent: 236
# shapiro-r all_received: 1213
# symes-k all_sent: 1309
# symes-k all_received: 1361
# storey-g all_sent: 133
# storey-g all_received: 223
# kuykendall-t all_sent: 150
# kuykendall-t all_received: 139
# hodge-j all_sent: 129
# hodge-j all_received: 526
# crandell-s all_sent: 149
# crandell-s all_received: 165
# lewis-a all_sent: 46
# lewis-a all_received: 1096
# shankman-j all_sent: 960
# shankman-j all_received: 539
# pereira-s all_sent: 106
# pereira-s all_received: 92
# whalley-g all_sent: 82
# whalley-g all_received: 416
# south-s all_sent: 21
# south-s all_received: 36
# taylor-m all_sent: 2002
# taylor-m all_received: 2124
# dasovich-j all_sent: 5027
# dasovich-j all_received: 5513
# horton-s all_sent: 307
# horton-s all_received: 386
# shackleton-s all_sent: 3950
# shackleton-s all_received: 3511
# ring-a all_sent: 106
# ring-a all_received: 72
# may-l all_sent: 41
# may-l all_received: 341
# lokey-t all_sent: 119
# lokey-t all_received: 443
# bailey-s all_sent: 135
# bailey-s all_received: 211
# fischer-m all_sent: 72
# fischer-m all_received: 263
# arora-h all_sent: 64
# arora-h all_received: 146
# lay-k all_sent: 14
# lay-k all_received: 1362
# kitchen-l all_sent: 1128
# kitchen-l all_received: 166
# donoho-l all_sent: 217
# donoho-l all_received: 167
# delainey-d all_sent: 721
# delainey-d all_received: 22
# rogers-b all_sent: 845
# rogers-b all_received: 1141
# lenhart-m all_sent: 1627
# lenhart-m all_received: 401
# hayslett-r all_sent: 460
# hayslett-r all_received: 370
# blair-l all_sent: 846
# blair-l all_received: 431
# mckay-b all_sent: 57
# mckay-b all_received: 184
# buy-r all_sent: 311
# buy-r all_received: 856
# linder-e all_sent: 6
# linder-e all_received: 27
# sager-e all_sent: 1074
# sager-e all_received: 935
# ruscitti-k all_sent: 185
# ruscitti-k all_received: 249
# mims-thurston-p all_sent: 167
# mims-thurston-p all_received: 622
# thomas-p all_sent: 155
# thomas-p all_received: 486
# corman-s all_sent: 629
# corman-s all_received: 361
# mclaughlin-e all_sent: 338
# mclaughlin-e all_received: 458
# swerzbin-m all_sent: 73
# swerzbin-m all_received: 142
# steffes-j all_sent: 1378
# steffes-j all_received: 506
# martin-t all_sent: 197
# martin-t all_received: 277
# maggi-m all_sent: 664
# maggi-m all_received: 842
# donohoe-t all_sent: 32
# donohoe-t all_received: 208
# mann-k all_sent: 3737
# mann-k all_received: 1760
# zufferli-j all_sent: 338
# zufferli-j all_received: 89
# tholt-j all_sent: 240
# tholt-j all_received: 268
# sanders-r all_sent: 1746
# sanders-r all_received: 1164
# platter-p all_sent: 107
# platter-p all_received: 179
# benson-r all_sent: 14
# benson-r all_received: 197
# brawner-s all_sent: 136
# brawner-s all_received: 155
# carson-m all_sent: 122
# carson-m all_received: 253
# mccarty-d all_sent: 189
# mccarty-d all_received: 176
# keiser-k all_sent: 364
# keiser-k all_received: 344
# dean-c all_sent: 93
# dean-c all_received: 366
# bass-e all_sent: 1282
# bass-e all_received: 545
# ermis-f all_sent: 18
# ermis-f all_received: 260
# perlingiere-d all_sent: 1786
# perlingiere-d all_received: 259
# staab-t all_sent: 112
# staab-t all_received: 229
# geaccone-t all_sent: 361
# geaccone-t all_received: 484
# gilbertsmith-d all_sent: 79
# gilbertsmith-d all_received: 132
# harris-s all_sent: 63
# harris-s all_received: 208
# parks-j all_sent: 559
# parks-j all_received: 773
# sturm-f all_sent: 137
# sturm-f all_received: 186
# love-p all_sent: 741
# love-p all_received: 423
# kaminski-v all_sent: 3714
# kaminski-v all_received: 2951
# motley-m all_sent: 14
# motley-m all_received: 86
# shively-h all_sent: 231
# shively-h all_received: 396
# meyers-a all_sent: 28
# meyers-a all_received: 51
# dickson-s all_sent: 189
# dickson-s all_received: 0
# saibi-e all_sent: 39
# saibi-e all_received: 358
# dorland-c all_sent: 479
# dorland-c all_received: 165
# lokay-m all_sent: 373
# lokay-m all_received: 1171
# merriss-s all_sent: 3
# merriss-s all_received: 21
# jones-t all_sent: 3827
# jones-t all_received: 4272
# rapp-b all_sent: 103
# rapp-b all_received: 287
# nemec-g all_sent: 1677
# nemec-g all_received: 2533
# skilling-j all_sent: 63
# skilling-j all_received: 962
# stclair-c all_sent: 1339
# stclair-c all_received: 136
# cuilla-m all_sent: 118
# cuilla-m all_received: 255
# keavey-p all_sent: 68
# keavey-p all_received: 357
# solberg-g all_sent: 65
# solberg-g all_received: 52
# holst-k all_sent: 36
# holst-k all_received: 188
# rodrique-r all_sent: 545
# rodrique-r all_received: 94
# ybarbo-p all_sent: 106
# ybarbo-p all_received: 445
# lucci-p all_sent: 235
# lucci-p all_received: 463
# salisbury-h all_sent: 139
# salisbury-h all_received: 447
# grigsby-m all_sent: 283
# grigsby-m all_received: 366
# stokley-c all_sent: 0
# stokley-c all_received: 0
# haedicke-m all_sent: 946
# haedicke-m all_received: 902
# pimenov-v all_sent: 73
# pimenov-v all_received: 224
# guzman-m all_sent: 358
# guzman-m all_received: 447
# quenet-j all_sent: 74
# quenet-j all_received: 76
# scott-s all_sent: 937
# scott-s all_received: 865
# ward-k all_sent: 674
# ward-k all_received: 350
# panus-s all_sent: 129
# panus-s all_received: 212
# allen-p all_sent: 473
# allen-p all_received: 280
# presto-k all_sent: 946
# presto-k all_received: 758
# ring-r all_sent: 101
# ring-r all_received: 261
# mcconnell-m all_sent: 680
# mcconnell-m all_received: 364
# hendrickson-s all_sent: 65
# hendrickson-s all_received: 161
# smith-m all_sent: 215
# smith-m all_received: 354
# williams-w3 all_sent: 570
# williams-w3 all_received: 500
# griffith-j all_sent: 244
# griffith-j all_received: 549
# scholtes-d all_sent: 125
# scholtes-d all_received: 59
# arnold-j all_sent: 756
# arnold-j all_received: 492
# reitmeyer-j all_sent: 57
# reitmeyer-j all_received: 275
# watson-k all_sent: 971
# watson-k all_received: 555
# gay-r all_sent: 287
# gay-r all_received: 76
# giron-d all_sent: 640
# giron-d all_received: 371
# weldon-c all_sent: 171
# weldon-c all_received: 209
# williams-j all_sent: 112
# williams-j all_received: 244
# whalley-l all_sent: 107
# whalley-l all_received: 478
# schoolcraft-d all_sent: 430
# schoolcraft-d all_received: 349
# white-s all_sent: 501
# white-s all_received: 846
# lavorato-j all_sent: 577
# lavorato-j all_received: 683
# badeer-r all_sent: 77
# badeer-r all_received: 70
# derrick-j all_sent: 564
# derrick-j all_received: 306
# sanchez-m all_sent: 102
# sanchez-m all_received: 47
# hain-m all_sent: 321
# hain-m all_received: 409
# richey-c all_sent: 261
# richey-c all_received: 64
# quigley-d all_sent: 505
# quigley-d all_received: 269
# heard-m all_sent: 783
# heard-m all_received: 289
# phanis-s all_sent: 0
# phanis-s all_received: 0
# schwieger-j all_sent: 130
# schwieger-j all_received: 131
# zipper-a all_sent: 349
# zipper-a all_received: 432
# gang-l all_sent: 90
# gang-l all_received: 392
# causholli-m all_sent: 444
# causholli-m all_received: 201
# semperger-c all_sent: 274
# semperger-c all_received: 240
# townsend-j all_sent: 33
# townsend-j all_received: 158
# neal-s all_sent: 386
# neal-s all_received: 520
# fossum-d all_sent: 980
# fossum-d all_received: 212
# mckay-j all_sent: 292
# mckay-j all_received: 206
# beck-s all_sent: 1073
# beck-s all_received: 1609
# hyvl-d all_sent: 674
# hyvl-d all_received: 720
# kean-s all_sent: 1291
# kean-s all_received: 3278

# %%
email_stats = {}

for person in emails_dictionary.emails:
    try:
        all_sent_dir = os.path.join(os.getcwd() + '/enron_mail/maildir/' + person, 'all_sent')
        all_received_dir = os.path.join(os.getcwd() + '/enron_mail/maildir/' + person, 'all_received')
        all_sent_items = os.listdir(all_sent_dir)
        all_received_items = os.listdir(all_received_dir)
        email_stats[person] = {'sent': len(all_sent_items), 'received': len(all_received_items)}
    except:
        continue

# %%
filename = "email_stats.csv"

with open(filename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    
    writer.writerow(['person', 'sent', 'received'])
    
    for person, stats in email_stats.items():
        writer.writerow([person, stats['sent'], stats['received']])
